# %%
import pandas as pd
import numpy as np

# %%
df_2016 = pd.read_csv('../data/2016/2016_all.csv')
df_2017 = pd.read_csv('../data/2017/2017_all.csv')
df_2018 = pd.read_csv('../data/2018/2018_all.csv')
df_2019 = pd.read_csv('../data/2019/2019_all.csv')
df_2020 = pd.read_csv('../data/2020/2020_April_Dec.csv')
df_2021 = pd.read_csv('../data/2021/2021_all.csv')
df_2022 = pd.read_csv('../data/2022/2022_all.csv')
# Out:
# /var/folders/r6/q0qh39ts70582wth4g1dhjhm0000gn/T/ipykernel_12344/1618741606.py:6: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2021 = pd.read_csv('../data/2021/2021_all.csv')

# %%
# Sample based on specific column
sample_df_19 = df_2019.groupby('Start.station.number').apply(lambda x: x.sample(frac=0.1))

# %%
sample_df
# Out:
#                               Duration           Start.date  \
# Start.station.number
# 0                    3398138       415  2019-12-31 21:06:09
#                      3262683      1340  2019-12-05 08:57:09
#                      3286668       410  2019-12-08 15:44:10
#                      3357731       667  2019-12-21 19:06:57
#                      3244062      1805  2019-12-02 21:07:27
# ...                                ...                  ...
# 32609                3234552       862  2019-11-30 14:26:07
#                      1314058       315  2019-06-06 13:05:23
#                      1900403       678  2019-07-27 14:30:57
#                      1738878       252  2019-07-13 14:09:42
#                      1709891      1443  2019-07-10 20:44:33
#
#                                          End.date  Start.station.number  \
# Start.station.number
# 0                    3398138  2019-12-31 21:13:05                     0
# ...

# %% [markdown]
# # Correct Appending Starts from Here

# %% [markdown]
# ### ----------------------------------------------------------------------

# %% [markdown]
# # Append start latitude and longitude for 2016 using 2021 as reference

# %%
x = df_2021

#x['start_station_id'] = pd.to_numeric(x['start_station_id'])
x = x.dropna()
x['start_station_id'] = x['start_station_id'].astype(int)

x = x.drop_duplicates(subset=['start_station_id'])

x = x[['start_station_id' , 'start_lat', 'start_lng']]

x = x.rename(columns = {'start_station_id':'Start.station.number'})

y = df_2016.merge(x , on='Start.station.number', how='left')
y
# Out:
# /var/folders/r6/q0qh39ts70582wth4g1dhjhm0000gn/T/ipykernel_12344/1244153496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['start_station_id'] = x['start_station_id'].astype(int)
#          Duration           Start.date             End.date  \
# 0             166  2016-01-01 00:06:58  2016-01-01 00:09:44
# 1             448  2016-01-01 00:10:20  2016-01-01 00:17:48
# 2             715  2016-01-01 00:13:52  2016-01-01 00:25:48
# 3             213  2016-01-01 00:15:29  2016-01-01 00:19:03
# 4             872  2016-01-01 00:16:16  2016-01-01 00:30:49
# ...           ...                  ...                  ...
# 3333989       614  2016-12-31 23:49:54  2017-01-01 00:00:09
# ...

# %% [markdown]
# # Append end latitude and longitude for 2016 using 2021 as reference

# %%
x = df_2021

#x['start_station_id'] = pd.to_numeric(x['start_station_id'])
x = x.dropna()
x['end_station_id'] = x['end_station_id'].astype(int)

x = x.drop_duplicates(subset=['end_station_id'])

x = x[['end_station_id' , 'end_lat', 'end_lng']]

x = x.rename(columns = {'end_station_id':'End.station.number'})

y = y.merge(x , on='End.station.number', how='left')
y
# Out:
# /var/folders/r6/q0qh39ts70582wth4g1dhjhm0000gn/T/ipykernel_12344/3169717017.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['end_station_id'] = x['end_station_id'].astype(int)
#          Duration           Start.date             End.date  \
# 0             166  2016-01-01 00:06:58  2016-01-01 00:09:44
# 1             448  2016-01-01 00:10:20  2016-01-01 00:17:48
# 2             715  2016-01-01 00:13:52  2016-01-01 00:25:48
# 3             213  2016-01-01 00:15:29  2016-01-01 00:19:03
# 4             872  2016-01-01 00:16:16  2016-01-01 00:30:49
# ...           ...                  ...                  ...
# 3333989       614  2016-12-31 23:49:54  2017-01-01 00:00:09
# 3333990       483  2016-12-31 23:51:58  2017-01-01 00:00:01
# ...

# %%
y["start_lng"].isna().sum()
y["end_lng"].isna().sum()
# Out:
# 5361

# %%
y.to_csv("../data/2016/df_2016_geospatial.csv", index=False) # about 5.5k NA's for both start and end geo coords

# %% [markdown]
# # Append start latitude and longitude for 2017 using 2021 as reference

# %%
x = df_2021

#x['start_station_id'] = pd.to_numeric(x['start_station_id'])
x = x.dropna()
x['start_station_id'] = x['start_station_id'].astype(int)

x = x.drop_duplicates(subset=['start_station_id'])

x = x[['start_station_id' , 'start_lat', 'start_lng']]

x = x.rename(columns = {'start_station_id':'Start.station.number'})

y = df_2017.merge(x , on='Start.station.number', how='left')
y
# Out:
# /var/folders/r6/q0qh39ts70582wth4g1dhjhm0000gn/T/ipykernel_12344/3560888567.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['start_station_id'] = x['start_station_id'].astype(int)
#          Duration           Start.date             End.date  \
# 0             221  2017-01-01 00:00:41  2017-01-01 00:04:23
# 1            1676  2017-01-01 00:06:53  2017-01-01 00:34:49
# 2            1356  2017-01-01 00:07:10  2017-01-01 00:29:47
# 3            1327  2017-01-01 00:07:22  2017-01-01 00:29:30
# 4            1636  2017-01-01 00:07:36  2017-01-01 00:34:52
# ...           ...                  ...                  ...
# 3757772       277  2017-12-31 23:43:17  2017-12-31 23:47:54
# ...

# %% [markdown]
# # Append end latitude and longitude for 2017 using 2021 as reference

# %%
x = df_2021

#x['start_station_id'] = pd.to_numeric(x['start_station_id'])
x = x.dropna()
x['end_station_id'] = x['end_station_id'].astype(int)

x = x.drop_duplicates(subset=['end_station_id'])

x = x[['end_station_id' , 'end_lat', 'end_lng']]

x = x.rename(columns = {'end_station_id':'End.station.number'})

y = y.merge(x , on='End.station.number', how='left')
y
# Out:
# /var/folders/r6/q0qh39ts70582wth4g1dhjhm0000gn/T/ipykernel_12344/3169717017.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['end_station_id'] = x['end_station_id'].astype(int)
#          Duration           Start.date             End.date  \
# 0             221  2017-01-01 00:00:41  2017-01-01 00:04:23
# 1            1676  2017-01-01 00:06:53  2017-01-01 00:34:49
# 2            1356  2017-01-01 00:07:10  2017-01-01 00:29:47
# 3            1327  2017-01-01 00:07:22  2017-01-01 00:29:30
# 4            1636  2017-01-01 00:07:36  2017-01-01 00:34:52
# ...           ...                  ...                  ...
# 3757772       277  2017-12-31 23:43:17  2017-12-31 23:47:54
# 3757773       399  2017-12-31 23:51:55  2017-12-31 23:58:35
# ...

# %%
print(y["start_lng"].isna().sum())
print(y["end_lng"].isna().sum())
# Out:
# 7219
# 7616

# %%
y.to_csv("../data/2017/df_2017_geospatial.csv", index=False) # about 7.5k NA's for both start and end geo coords

# %% [markdown]
# # Append start latitude and longitude for 2018 using 2021 as reference

# %%
x = df_2021

#x['start_station_id'] = pd.to_numeric(x['start_station_id'])
x = x.dropna()
x['start_station_id'] = x['start_station_id'].astype(int)

x = x.drop_duplicates(subset=['start_station_id'])

x = x[['start_station_id' , 'start_lat', 'start_lng']]

x = x.rename(columns = {'start_station_id':'Start.station.number'})

y = df_2018.merge(x , on='Start.station.number', how='left')
y
# Out:
# /var/folders/r6/q0qh39ts70582wth4g1dhjhm0000gn/T/ipykernel_12344/392504582.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['start_station_id'] = x['start_station_id'].astype(int)
#          Duration           Start.date             End.date  \
# 0             552  2018-01-01 00:05:06  2018-01-01 00:14:18
# 1            1282  2018-01-01 00:14:30  2018-01-01 00:35:53
# 2            1265  2018-01-01 00:14:53  2018-01-01 00:35:58
# 3             578  2018-01-01 00:15:31  2018-01-01 00:25:09
# 4             372  2018-01-01 00:18:02  2018-01-01 00:24:15
# ...           ...                  ...                  ...
# 3542679      3313  2018-12-31 23:37:22  2019-01-01 00:32:36
# 3542680       888  2018-12-31 23:42:18  2018-12-31 23:57:07
# ...

# %% [markdown]
# # Append end latitude and longitude for 2017 using 2021 as reference

# %%
x = df_2021

#x['start_station_id'] = pd.to_numeric(x['start_station_id'])
x = x.dropna()
x['end_station_id'] = x['end_station_id'].astype(int)

x = x.drop_duplicates(subset=['end_station_id'])

x = x[['end_station_id' , 'end_lat', 'end_lng']]

x = x.rename(columns = {'end_station_id':'End.station.number'})

y = y.merge(x , on='End.station.number', how='left')
y
# Out:
# /var/folders/r6/q0qh39ts70582wth4g1dhjhm0000gn/T/ipykernel_12344/3169717017.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['end_station_id'] = x['end_station_id'].astype(int)
#          Duration           Start.date             End.date  \
# 0             552  2018-01-01 00:05:06  2018-01-01 00:14:18
# 1            1282  2018-01-01 00:14:30  2018-01-01 00:35:53
# 2            1265  2018-01-01 00:14:53  2018-01-01 00:35:58
# 3             578  2018-01-01 00:15:31  2018-01-01 00:25:09
# 4             372  2018-01-01 00:18:02  2018-01-01 00:24:15
# ...           ...                  ...                  ...
# 3542679      3313  2018-12-31 23:37:22  2019-01-01 00:32:36
# 3542680       888  2018-12-31 23:42:18  2018-12-31 23:57:07
# ...

# %%
print(y["start_lng"].isna().sum())
print(y["end_lng"].isna().sum())
# Out:
# 5654
# 5851

# %%
y.to_csv("../data/2018/df_2018_geospatial.csv", index=False) # about 5.5k NA's for both start and end geo coords

# %% [markdown]
# # Append start latitude and longitude for 2019 using 2021 as reference

# %%
x = df_2021

#x['start_station_id'] = pd.to_numeric(x['start_station_id'])
x = x.dropna()
x['start_station_id'] = x['start_station_id'].astype(int)

x = x.drop_duplicates(subset=['start_station_id'])

x = x[['start_station_id' , 'start_lat', 'start_lng']]

x = x.rename(columns = {'start_station_id':'Start.station.number'})

y = df_2019.merge(x , on='Start.station.number', how='left')
y
# Out:
# /var/folders/r6/q0qh39ts70582wth4g1dhjhm0000gn/T/ipykernel_12344/474960954.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['start_station_id'] = x['start_station_id'].astype(int)
#          Duration           Start.date             End.date  \
# 0             230  2019-01-01 00:04:48  2019-01-01 00:08:39
# 1            1549  2019-01-01 00:06:37  2019-01-01 00:32:27
# 2             177  2019-01-01 00:08:46  2019-01-01 00:11:44
# 3             228  2019-01-01 00:08:47  2019-01-01 00:12:35
# 4            1300  2019-01-01 00:12:29  2019-01-01 00:34:10
# ...           ...                  ...                  ...
# 3398412       130  2019-12-31 23:57:36  2019-12-31 23:59:46
# 3398413       664  2019-12-31 23:57:47  2020-01-01 00:08:51
# ...

# %% [markdown]
# # Append end latitude and longitude for 2019 using 2021 as reference

# %%
x = df_2021

#x['start_station_id'] = pd.to_numeric(x['start_station_id'])
x = x.dropna()
x['end_station_id'] = x['end_station_id'].astype(int)

x = x.drop_duplicates(subset=['end_station_id'])

x = x[['end_station_id' , 'end_lat', 'end_lng']]

x = x.rename(columns = {'end_station_id':'End.station.number'})

y = y.merge(x , on='End.station.number', how='left')
y
# Out:
# /var/folders/r6/q0qh39ts70582wth4g1dhjhm0000gn/T/ipykernel_12344/3169717017.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['end_station_id'] = x['end_station_id'].astype(int)
#          Duration           Start.date             End.date  \
# 0             230  2019-01-01 00:04:48  2019-01-01 00:08:39
# 1            1549  2019-01-01 00:06:37  2019-01-01 00:32:27
# 2             177  2019-01-01 00:08:46  2019-01-01 00:11:44
# 3             228  2019-01-01 00:08:47  2019-01-01 00:12:35
# 4            1300  2019-01-01 00:12:29  2019-01-01 00:34:10
# ...           ...                  ...                  ...
# 3398412       130  2019-12-31 23:57:36  2019-12-31 23:59:46
# 3398413       664  2019-12-31 23:57:47  2020-01-01 00:08:51
# ...

# %%
print(y["start_lng"].isna().sum())
print(y["end_lng"].isna().sum())
# Out:
# 1032
# 954

# %%
y.to_csv("../data/2019/df_2019_geospatial.csv", index=False) # about 1k NA's for both start and end geo coords

# %% [markdown]
# # Append start latitude and longitude for 2020 (Jan-March) using 2021 as reference

# %%
df_2020_Jan_March = pd.read_csv('../data/2020_Jan_March/2020_Jan_March.csv')
x = df_2021

#x['start_station_id'] = pd.to_numeric(x['start_station_id'])
x = x.dropna()
x['start_station_id'] = x['start_station_id'].astype(int)

x = x.drop_duplicates(subset=['start_station_id'])

x = x[['start_station_id' , 'start_lat', 'start_lng']]

x = x.rename(columns = {'start_station_id':'Start.station.number'})

y = df_2020_Jan_March.merge(x , on='Start.station.number', how='left')
y
# Out:
# /var/folders/r6/q0qh39ts70582wth4g1dhjhm0000gn/T/ipykernel_12344/3473888966.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['start_station_id'] = x['start_station_id'].astype(int)
#         Duration           Start.date             End.date  \
# 0            506  2020-01-01 00:00:59  2020-01-01 00:09:26
# 1           1050  2020-01-01 00:01:16  2020-01-01 00:18:47
# 2           1687  2020-01-01 00:02:42  2020-01-01 00:30:50
# 3            182  2020-01-01 00:02:44  2020-01-01 00:05:47
# 4           1002  2020-01-01 00:06:12  2020-01-01 00:22:54
# ...          ...                  ...                  ...
# 537395       673  2020-03-31 23:17:58  2020-03-31 23:29:12
# 537396       514  2020-03-31 23:18:13  2020-03-31 23:26:47
# ...

# %% [markdown]
# # Append end latitude and longitude for 2020 (Jan-March) using 2021 as reference

# %%
x = df_2021

#x['start_station_id'] = pd.to_numeric(x['start_station_id'])
x = x.dropna()
x['end_station_id'] = x['end_station_id'].astype(int)

x = x.drop_duplicates(subset=['end_station_id'])

x = x[['end_station_id' , 'end_lat', 'end_lng']]

x = x.rename(columns = {'end_station_id':'End.station.number'})

y = y.merge(x , on='End.station.number', how='left')
y
# Out:
# /var/folders/r6/q0qh39ts70582wth4g1dhjhm0000gn/T/ipykernel_12344/3169717017.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['end_station_id'] = x['end_station_id'].astype(int)
#         Duration           Start.date             End.date  \
# 0            506  2020-01-01 00:00:59  2020-01-01 00:09:26
# 1           1050  2020-01-01 00:01:16  2020-01-01 00:18:47
# 2           1687  2020-01-01 00:02:42  2020-01-01 00:30:50
# 3            182  2020-01-01 00:02:44  2020-01-01 00:05:47
# 4           1002  2020-01-01 00:06:12  2020-01-01 00:22:54
# ...          ...                  ...                  ...
# 537395       673  2020-03-31 23:17:58  2020-03-31 23:29:12
# 537396       514  2020-03-31 23:18:13  2020-03-31 23:26:47
# ...

# %%
print(y["start_lng"].isna().sum())
print(y["end_lng"].isna().sum())
# Out:
# 301
# 338

# %%
y.to_csv("../data/2020_Jan_March/df_2020_Jan_March_geospatial.csv", index=False) # about 300 NA's for both start and end geo coords
